# %% [markdown]
# # Modelo de Recomendación Item-Item:
#
#
# El modelo debe establecer una relación ítem-ítem, donde la recomendación de elementos similares se basa en la medida de similitud entre un ítem dado y el resto. En este contexto, el modelo toma como entrada un juego específico y genera como salida una lista de juegos recomendados. Para lograr esto, se recomienda aplicar la métrica de similitud del coseno.

# %% [markdown]
# Para lo anterior se hace uso de los datos guardados en la carpeta "Clean_Data" sobre el archivo "SGames_CD.csv" donde desde el inicio se permitió que los datos en genero quedaran en listas sin extender porque podría facilitar el desarrollo del modelo. Aunque no se descarta la opción de extender los generos.

# %% [markdown]
# ### 1. Importar las librerías necesarias para la creación del modelo y descarga de datos:

# %%
import pandas as pd                                                 # Para abrir y editar los archivos 
import numpy as np                                                  # Para realizar cálculos

#----------------------------------------------------------------------------------------------------------------------------------

from sklearn.feature_extraction.text import CountVectorizer         # Para convertir las características analizadas en matrices
from sklearn.metrics.pairwise import cosine_similarity              # Para calcular la similitud de coseno de la matriz

# %% [markdown]
# ### 2. Abrir y arreglar los datos para que no hayan registros nulos:

# %%
Model_Data = pd.read_csv('Clean_Data\\SGames_CD.csv', quotechar='"')
Model_Data.head(2)
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1  Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
#
#               app_name release_date  \
# 0  Lost Summoner Kitty   2018-01-04
# 1            Ironbound   2018-01-04
#
#                                                specs  price  early_access  \
# 0                                  ['Single-player']   4.99         False
# 1  ['Single-player', 'Multi-player', 'Online Mult...   0.00         False
#
#          id         developer  release_year
# 0  761140.0         Kotoshiro          2018
# 1  643980.0  Secret Level SRL          2018

# %%
Model_Data=Model_Data[['id','genres','publisher','release_date','specs','price','early_access','developer','release_year']]
Model_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32133 entries, 0 to 32132
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            32132 non-null  float64
#  1   genres        31994 non-null  object
#  2   publisher     24062 non-null  object
#  3   release_date  29781 non-null  object
#  4   specs         31463 non-null  object
#  5   price         30267 non-null  float64
#  6   early_access  32133 non-null  bool
#  7   developer     28834 non-null  object
#  8   release_year  32133 non-null  int64
# dtypes: bool(1), float64(2), int64(1), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Se realizan los cambios para garantizar que no hay datos nulos, se eliminan datos que tengan al mismo tiempo nulos en año y genero, para los demás valores se imputa con desconocido:

# %%
# Eliminar registros con valores nulos en 'genres' y valores de 0 en 'release_year'

Model_Data = Model_Data[(Model_Data['release_year'] != 0) & (Model_Data['genres'].notnull())]

# Reemplazar valores nulos en 'genres' con 'desconocido'
Model_Data['genres'] = Model_Data['genres'].fillna('a stranger')

# Reemplazar valores nulos en 'developer' y 'publisher' con 'desconocido':
Model_Data['developer'] = Model_Data['developer'].fillna('a stranger')
Model_Data['publisher'] = Model_Data['publisher'].fillna('a stranger')

# Colocar 0 en los valores nulos de 'price'
Model_Data['price'] = Model_Data['price'].fillna(0)

# Eliminar registros con valores nulos en 'genres'
Model_Data = Model_Data.dropna(subset=['genres'])

# Eliminar la columna 'release_date'
Model_Data = Model_Data.drop(columns=['release_date'])

# Colocar 'not specified' en los valores nulos de la columna 'specs'
Model_Data['specs'] = Model_Data['specs'].fillna('not specified')

# Verificar los cambios
Model_Data.head(-5)
# Out:
#              id                                             genres  \
# 0      761140.0  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      643980.0       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2      670290.0  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3      767400.0                  ['Action', 'Adventure', 'Casual']
# 5      772540.0              ['Action', 'Adventure', 'Simulation']
# ...         ...                                                ...
# 32122  761480.0                             ['Adventure', 'Indie']
# 32123  771810.0                   ['Action', 'Adventure', 'Indie']
# 32124  767590.0                                ['Casual', 'Indie']
# 32125  747320.0                                   ['Indie', 'RPG']
# 32126  769330.0                                ['Casual', 'Indie']
#
#                  publisher                                              specs  \
# 0                Kotoshiro                                  ['Single-player']
# 1         Making Fun, Inc.  ['Single-player', 'Multi-player', 'Online Mult...
# 2             Poolians.com  ['Single-player', 'Multi-player', 'Online Mult...
# 3                     彼岸领域                                  ['Single-player']
# 5      Trickjump Games Ltd            ['Single-player', 'Steam Achievements']
# ...                    ...                                                ...
# 32122         Phil Fortier            ['Single-player', 'Steam Achievements']
# 32123   Retro Army Limited            ['Single-player', 'Captions available']
# 32124   OrtiGames/OrtiSoft  ['Single-player', 'Shared/Split Screen', 'Stea...
# 32125               INGAME  ['Single-player', 'Steam Achievements', 'Steam...
# 32126             Riviysky                                  ['Single-player']
#
#        price  early_access                                  developer  \
# 0       4.99         False                                  Kotoshiro
# 1       0.00         False                           Secret Level SRL
# 2       0.00         False                               Poolians.com
# 3       0.99         False                                       彼岸领域
# 5       3.99         False                        Trickjump Games Ltd
# ...      ...           ...                                        ...
# 32122   0.99         False                               Phil Fortier
# 32123   0.00         False                         Retro Army Limited
# 32124   0.99         False  Oscar Ortigueira López,OrtiGames/OrtiSoft
# 32125  14.99         False                                     INGAME
# 32126   0.00         False                                   Riviysky
#
#        release_year
# 0              2018
# 1              2018
# 2              2017
# 3              2017
# 5              2018
# ...             ...
# 32122          2018
# 32123          2018
# 32124          2018
# 32125          2018
# 32126          2018
#
# [29639 rows x 8 columns]

# %% [markdown]
# Se obtiene una base sin nulos para trabajar:

# %%
Model_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29644 entries, 0 to 32131
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            29644 non-null  float64
#  1   genres        29644 non-null  object
#  2   publisher     29644 non-null  object
#  3   specs         29644 non-null  object
#  4   price         29644 non-null  float64
#  5   early_access  29644 non-null  bool
#  6   developer     29644 non-null  object
#  7   release_year  29644 non-null  int64
# dtypes: bool(1), float64(2), int64(1), object(4)
# memory usage: 1.8+ MB

# %%
# Contar registros con valor 0 en 'release_year'
count_zero_release_year = (Model_Data['release_year'] == 0).sum()

# Imprimir el resultado
print("Cantidad de registros con release_year igual a 0:", count_zero_release_year)
# Out:
# Cantidad de registros con release_year igual a 0: 0

# %% [markdown]
# ### 3. Desarrollo del modelo "Similitud del Coseno":

# %% [markdown]
# 3.1. Convertir "genres" y "specs" en cadena para facilitar el desarrollo del modelo:

# %%
# Eliminar comillas, corchetes, comas y reemplazar guiones por espacios en 'genres'
Model_Data['genres'] = Model_Data['genres'].astype(str).str.replace('[', '').str.replace(']', '').str.replace("'", "").str.replace(",", "").str.replace("-", " ")

# Eliminar comillas, corchetes, comas y reemplazar guiones por espacios en 'specs'
Model_Data['specs'] = Model_Data['specs'].astype(str).str.replace('[', '').str.replace(']', '').str.replace("'", "").str.replace(",", "").str.replace("-", " ")

# Verificar los cambios
Model_Data.head()
# Out:
#          id                                       genres            publisher  \
# 0  761140.0      Action Casual Indie Simulation Strategy            Kotoshiro
# 1  643980.0              Free to Play Indie RPG Strategy     Making Fun, Inc.
# 2  670290.0  Casual Free to Play Indie Simulation Sports         Poolians.com
# 3  767400.0                      Action Adventure Casual                 彼岸领域
# 5  772540.0                  Action Adventure Simulation  Trickjump Games Ltd
#
#                                                specs  price  early_access  \
# 0                                      Single player   4.99         False
# 1  Single player Multi player Online Multi Player...   0.00         False
# 2  Single player Multi player Online Multi Player...   0.00         False
# 3                                      Single player   0.99         False
# 5                   Single player Steam Achievements   3.99         False
#
#              developer  release_year
# 0            Kotoshiro          2018
# 1     Secret Level SRL          2018
# 2         Poolians.com          2017
# 3                 彼岸领域          2017
# 5  Trickjump Games Ltd          2018

# %% [markdown]
# 3.2. Tokenizar genres y specs para facilitar al modelo el análisis (no se exige en estos modelos pero parece apropiado) también se normaliza. Para developer y Publisher se decide codificar:

# %%
# Tokenizar y normalizar 'genres'
Model_Data['genres'] = Model_Data['genres'].astype(str).str.lower().str.replace('[', '').str.replace(']', '').str.replace("'", "").str.replace(",", "").str.replace("-", " ")

# Tokenizar y normalizar 'specs'
Model_Data['specs'] = Model_Data['specs'].astype(str).str.lower().str.replace('[', '').str.replace(']', '').str.replace("'", "").str.replace(",", "").str.replace("-", " ")

# %%
# Codificación de dummies para 'publisher' y 'developer'
#Model_Data = pd.get_dummies(Model_Data, columns=['publisher', 'developer'], drop_first=True)


# Verificar los cambios
Model_Data.head()
# Out:
#          id                                       genres            publisher  \
# 0  761140.0      action casual indie simulation strategy            Kotoshiro
# 1  643980.0              free to play indie rpg strategy     Making Fun, Inc.
# 2  670290.0  casual free to play indie simulation sports         Poolians.com
# 3  767400.0                      action adventure casual                 彼岸领域
# 5  772540.0                  action adventure simulation  Trickjump Games Ltd
#
#                                                specs  price  early_access  \
# 0                                      single player   4.99         False
# 1  single player multi player online multi player...   0.00         False
# 2  single player multi player online multi player...   0.00         False
# 3                                      single player   0.99         False
# 5                   single player steam achievements   3.99         False
#
#              developer  release_year  \
# 0            Kotoshiro          2018
# 1     Secret Level SRL          2018
# 2         Poolians.com          2017
# 3                 彼岸领域          2017
# 5  Trickjump Games Ltd          2018
#
#                                    combined_features
# 0  action casual indie simulation strategy single...
# 1  free to play indie rpg strategy single player ...
# 2  casual free to play indie simulation sports si...
# 3              action adventure casual single player
# 5  action adventure simulation single player stea...

# %% [markdown]
# 3.3. Exportar dataframe a CSV para que sea insumo del modelo, aunque lo más probable es que solo se requiera la matriz de similitud para el modelo:

# %%
# Exportar el DataFrame a CSV:

#Model_Data.to_csv('Data_Queries/Model_Data.csv', index=False)
#print(f"DataFrame exportado a {'Data_Queries/Model_Data.csv'}")

#Acción suspendida, dado que el df no fué util en la api. Se procede a crear un df arreglado para facilitar las funciones
# Out:
# DataFrame exportado a Data_Queries/Model_Data.csv

# %% [markdown]
# 3.3. Aplicar el modelo de similitud de coseno:

# %%
# Combina las columnas 'genres' y 'specs' en una sola columna de texto
Model_Data['combined_features'] = Model_Data['genres'] + ' ' + Model_Data['specs']

# Selecciona las características relevantes (One-Hot Encoded + combined_features)
text_features = pd.get_dummies(Model_Data['combined_features'])
encoded_features = pd.get_dummies(Model_Data[['publisher', 'developer']], prefix=['publisher', 'developer'])
features = pd.concat([encoded_features, text_features], axis=1)

# Utiliza CountVectorizer para convertir la columna 'combined_features' en una matriz de recuentos
vectorizer = CountVectorizer()
text_features_matrix = vectorizer.fit_transform(Model_Data['combined_features'])

# Combina la matriz de recuentos con las características relevantes
all_features_matrix = pd.concat([pd.DataFrame(text_features_matrix.toarray()), features.reset_index(drop=True)], axis=1)

# Calcula la similitud de coseno entre los vectores
cosine_sim = cosine_similarity(all_features_matrix, all_features_matrix)

# Imprime la matriz de similitud de coseno
print(cosine_sim)
# Out:
# [[1.         0.31192515 0.41105415 ... 0.34503278 0.32659863 0.35082321]
#  [0.31192515 1.         0.67161876 ... 0.4663724  0.50937163 0.45596075]
#  [0.41105415 0.67161876 1.         ... 0.28365431 0.28767798 0.30901572]
#  ...
#  [0.34503278 0.4663724  0.28365431 ... 1.         0.56343617 0.72627304]
#  [0.32659863 0.50937163 0.28767798 ... 0.56343617 1.         0.5728919 ]
#  [0.35082321 0.45596075 0.30901572 ... 0.72627304 0.5728919  1.        ]]

# %% [markdown]
# 3.4. Crear una función de similitudo de coseno para iterar en la base de datos:

# %%
def similitud (id):

# Elegir un ítem específico (cambiar 'selected_item_id' por el ID deseado)
    selected_item_id = 	id

# Obtener la fila correspondiente al ítem seleccionado
    selected_item_index = Model_Data[Model_Data['id'] == selected_item_id].index[0]

# Calcular la similitud de coseno entre el ítem seleccionado y todos los demás ítems
    cosine_similarities = cosine_sim[selected_item_index]

# Obtener los índices de los ítems más similares (excluyendo el propio ítem seleccionado)
    similar_items_indices = np.argsort(cosine_similarities)[::-1][1:6]

# Obtener los IDs de los ítems más similares
    similar_item_ids = Model_Data.loc[similar_items_indices, 'id'].tolist()

    return id,similar_item_ids

# %% [markdown]
# 3.5. Probar función:

# %%
similitud(772540)
# Out:
# (772540, [768880.0, 774276.0, 774277.0, 773650.0, 237740.0])

# %% [markdown]
# 3.6. Iterar en la base de datos, para obtener para cada id los juesgos recomendados:

# %%
dic_similitud = {}

for i in Model_Data['id']:
    try:
        value = similitud(i)
        if value == i:
            continue
        else:
            dic_similitud[i] = value
    except Exception as e:
        print(f"Error para el ID {i}: {str(e)}")
# Out:
# Error para el ID 761140.0: '[14232] not in index'
# Error para el ID 643980.0: '[19795] not in index'
# Error para el ID 774278.0: '[3372] not in index'
# Error para el ID 775881.0: '[6665] not in index'
# Error para el ID 752360.0: '[7425] not in index'
# Error para el ID 766850.0: '[22] not in index'
# Error para el ID 773120.0: '[11308] not in index'
# Error para el ID 754360.0: '[12464] not in index'
# Error para el ID 759920.0: '[13224] not in index'
# Error para el ID 764280.0: '[45] not in index'
# Error para el ID 4230.0: '[26860] not in index'
# Error para el ID 6510.0: '[13676] not in index'
# Error para el ID 7650.0: '[74] not in index'
# Error para el ID 2300.0: '[20742] not in index'
# Error para el ID 4580.0: '[13507] not in index'
# Error para el ID 4760.0: '[26062] not in index'
# Error para el ID 12500.0: '[13513, 10428] not in index'
# Error para el ID 16180.0: '[51, 26062] not in index'
# Error para el ID 15970.0: '[45] not in index'
# Error para el ID 15930.0: '[6554] not in index'
# Error para el ID 15240.0: '[45] not in index'
# Error para el ID 12540.0: '[12463] not in index'
# Error para el ID 11050.0: '[12463] not in index'
# Error para el ID 11040.0: '[9387] not in index'
# Error para el ID 19500.0: '[42, 10428] not in index'
# Error para el ID 12360.0: '[27137] not in index'
# Error para el ID 19830.0: '[5368] not in index'
# Error para el ID 4460.0: '[19446] not in index'
# Error para el ID 1230.0: '[9890] not in index'
# Error para el ID 19900.0: '[18782] not in index'
# Error para el ID 11240.0: '[20962] not in index'
# Error para el ID 275144.0: '[612] not in index'
# Error para el ID 256521.0: '[13507] not in index'
# Error para el ID 256535.0: '[15251] not in index'
# Error para el ID 17470.0: '[20879] not in index'
# Error para el ID 12770.0: '[21648] not in index'
# Error para el ID 11340.0: '[9996] not in index'
# Error para el ID 26006.0: '[8450] not in index'
# Error para el ID 11330.0: '[24732] not in index'
# Error para el ID 29560.0: '[22349] not in index'
# Error para el ID 16060.0: '[5726, 7003] not in index'
# Error para el ID 22330.0: '[12025] not in index'
# Error para el ID 32740.0: '[28875, 14913] not in index'
# Error para el ID 6080.0: '[9122] not in index'
# Error para el ID 6060.0: '[510] not in index'
# Error para el ID 35300.0: '[23788] not in index'
# Error para el ID 33520.0: '[15579, 21787] not in index'
# Error para el ID 11390.0: '[14927] not in index'
# Error para el ID 43100.0: '[21828] not in index'
# Error para el ID 39392.0: '[17664] not in index'
# Error para el ID 37600.0: '[26860] not in index'
# Error para el ID 901735.0: '[43] not in index'
# Error para el ID 39560.0: '[612] not in index'
# Error para el ID 17450.0: '[13578] not in index'
# Error para el ID 24790.0: '[43] not in index'
# Error para el ID 22370.0: '[358] not in index'
# Error para el ID 38070.0: '[11634] not in index'
# Error para el ID 17570.0: '[4468] not in index'
# Error para el ID 38120.0: '[15889] not in index'
# Error para el ID 25960.0: '[10350] not in index'
# Error para el ID 10695.0: '[9800] not in index'
# Error para el ID 40930.0: '[14213] not in index'
# Error para el ID 39640.0: '[10350] not in index'
# Error para el ID 39630.0: '[6801] not in index'
# Error para el ID 50940.0: '[12943, 10304] not in index'
# Error para el ID 19080.0: '[506] not in index'
# Error para el ID 33650.0: '[13655] not in index'
# Error para el ID 33660.0: '[13655] not in index'
# Error para el ID 34281.0: '[13655] not in index'
# Error para el ID 34272.0: '[13655] not in index'
# Error para el ID 34270.0: '[8997] not in index'
# Error para el ID 34276.0: '[13655] not in index'
# Error para el ID 25760.0: '[13816] not in index'
# Error para el ID 25762.0: '[20360] not in index'
# Error para el ID 22600.0: '[17706] not in index'
# Error para el ID 25761.0: '[469] not in index'
# Error para el ID 50145.0: '[4468] not in index'
# Error para el ID 34841.0: '[42] not in index'
# Error para el ID 70300.0: '[23692] not in index'
# Error para el ID 38600.0: '[11661, 24978] not in index'
# Error para el ID 24082.0: '[13536] not in index'
# Error para el ID 41060.0: '[13576] not in index'
# Error para el ID 901553.0: '[510, 509] not in index'
# Error para el ID 50620.0: '[510] not in index'
# Error para el ID 2850.0: '[506] not in index'
# Error para el ID 70210.0: '[506] not in index'
# Error para el ID 57800.0: '[10304] not in index'
# Error para el ID 50000.0: '[13930] not in index'
# Error para el ID 34317.0: '[26649] not in index'
# Error para el ID 71112.0: '[26649] not in index'
# Error para el ID 71113.0: '[19623] not in index'
# Error para el ID 35460.0: '[10565, 18976] not in index'
# Error para el ID 63700.0: '[8088] not in index'
# Error para el ID 46362.0: '[8088] not in index'
# Error para el ID 49320.0: '[8088] not in index'
# Error para el ID 72400.0: '[8088] not in index'
# Error para el ID 33950.0: '[8091] not in index'
# Error para el ID 42700.0: '[510] not in index'
# Error para el ID 33770.0: '[612] not in index'
# Error para el ID 18408.0: '[18976] not in index'
# Error para el ID 55100.0: '[22185] not in index'
# Error para el ID 56434.0: '[23721] not in index'
# Error para el ID 56536.0: '[28160] not in index'
# Error para el ID 620.0: '[19237, 23488] not in index'
# Error para el ID 56482.0: '[6801] not in index'
# Error para el ID 56438.0: '[779] not in index'
# Error para el ID 73014.0: '[5457] not in index'
# Error para el ID 7530.0: '[5457] not in index'
# Error para el ID 91810.0: '[5457] not in index'
# Error para el ID 46760.0: '[23721] not in index'
# Error para el ID 44660.0: '[21770] not in index'
# Error para el ID 42903.0: '[17067, 14178] not in index'
# Error para el ID 92803.0: '[13618] not in index'
# Error para el ID 42230.0: '[23083] not in index'
# Error para el ID 99612.0: '[18088, 13618] not in index'
# Error para el ID 91604.0: '[24260] not in index'
# Error para el ID 97107.0: '[10030] not in index'
# Error para el ID 55150.0: '[2571] not in index'
# Error para el ID 110600.0: '[17672] not in index'
# Error para el ID 113200.0: '[13578] not in index'
# Error para el ID 901776.0: '[12876] not in index'
# Error para el ID 201100.0: '[790] not in index'
# Error para el ID 45770.0: '[23647] not in index'
# Error para el ID 18080.0: '[12964] not in index'
# Error para el ID 57696.0: '[4853] not in index'
# Error para el ID 201272.0: '[5368] not in index'
# Error para el ID 46350.0: '[23131] not in index'
# Error para el ID 24083.0: '[28694] not in index'
# Error para el ID 64017.0: '[28694] not in index'
# Error para el ID 35720.0: '[4468] not in index'
# Error para el ID 204010.0: '[11774] not in index'
# Error para el ID 200610.0: '[17206, 8976] not in index'
# Error para el ID 65244.0: '[13064, 13806] not in index'
# Error para el ID 24480.0: '[22360] not in index'
# Error para el ID 42968.0: '[13059, 16944] not in index'
# Error para el ID 203210.0: '[14001] not in index'
# Error para el ID 45774.0: '[21939, 22087] not in index'
# Error para el ID 203772.0: '[11544] not in index'
# Error para el ID 92620.0: '[27545] not in index'
# Error para el ID 108710.0: '[612] not in index'
# Error para el ID 108110.0: '[509] not in index'
# Error para el ID 55381.0: '[865] not in index'
# Error para el ID 205690.0: '[932] not in index'
# Error para el ID 206521.0: '[9564, 11488] not in index'
# Error para el ID 65246.0: '[13224] not in index'
# Error para el ID 73060.0: '[10005] not in index'
# Error para el ID 207250.0: '[6801] not in index'
# Error para el ID 55382.0: '[22087] not in index'
# Error para el ID 102850.0: '[9802] not in index'
# Error para el ID 208640.0: '[509] not in index'
# Error para el ID 204383.0: '[12474] not in index'
# Error para el ID 90207.0: '[19788] not in index'
# Error para el ID 213370.0: '[865] not in index'
# Error para el ID 204900.0: '[28472] not in index'
# Error para el ID 1840.0: '[6965, 6997] not in index'
# Error para el ID 98421.0: '[23644] not in index'
# Error para el ID 207650.0: '[21520] not in index'
# Error para el ID 209270.0: '[23692] not in index'
# Error para el ID 212010.0: '[12751] not in index'
# Error para el ID 216462.0: '[1847] not in index'
# Error para el ID 215246.0: '[42] not in index'
# Error para el ID 206114.0: '[19781] not in index'
# Error para el ID 206142.0: '[27279] not in index'
# Error para el ID 219910.0: '[13595] not in index'
# Error para el ID 215470.0: '[6055] not in index'
# Error para el ID 215245.0: '[28160] not in index'
# Error para el ID 219760.0: '[8127] not in index'
# Error para el ID 222140.0: '[15053] not in index'
# Error para el ID 200490.0: '[19931, 6965] not in index'
# Error para el ID 215311.0: '[14622] not in index'
# Error para el ID 216421.0: '[28117] not in index'
# Error para el ID 216420.0: '[13179] not in index'
# Error para el ID 223592.0: '[23647] not in index'
# Error para el ID 65216.0: '[19478] not in index'
# Error para el ID 225640.0: '[13103] not in index'
# Error para el ID 209801.0: '[14349] not in index'
# Error para el ID 222076.0: '[27955] not in index'
# Error para el ID 220440.0: '[12340] not in index'
# Error para el ID 210083.0: '[9882] not in index'
# Error para el ID 231140.0: '[14395] not in index'
# Error para el ID 222101.0: '[22204] not in index'
# Error para el ID 223793.0: '[19862] not in index'
# Error para el ID 223280.0: '[18265] not in index'
# Error para el ID 208810.0: '[21805] not in index'
# Error para el ID 234780.0: '[18598] not in index'
# Error para el ID 208814.0: '[9967] not in index'
# Error para el ID 230650.0: '[26438] not in index'
# Error para el ID 222576.0: '[15443] not in index'
# Error para el ID 203343.0: '[5454, 20274, 5451, 10674] not in index'
# Error para el ID 208817.0: '[12193] not in index'
# Error para el ID 222575.0: '[18883] not in index'
# Error para el ID 219447.0: '[23747] not in index'
# Error para el ID 208791.0: '[8380] not in index'
# Error para el ID 237570.0: '[3600] not in index'
# Error para el ID 229480.0: '[23651] not in index'
# Error para el ID 226663.0: '[7232] not in index'
# Error para el ID 2028850.0: '[18751] not in index'
# Error para el ID 218550.0: '[8375] not in index'
# Error para el ID 232647.0: '[8552] not in index'
# Error para el ID 224166.0: '[25774] not in index'
# Error para el ID 239380.0: '[3600] not in index'
# Error para el ID 210944.0: '[19510] not in index'
# Error para el ID 243360.0: '[4282] not in index'
# Error para el ID 241410.0: '[23487] not in index'
# Error para el ID 230690.0: '[16944, 16946] not in index'
# Error para el ID 231465.0: '[15128] not in index'
# Error para el ID 212894.0: '[23481] not in index'
# Error para el ID 222591.0: '[21177] not in index'
# Error para el ID 233840.0: '[1529] not in index'
# Error para el ID 244230.0: '[1529] not in index'
# Error para el ID 246562.0: '[1529] not in index'
# Error para el ID 205637.0: '[1529] not in index'
# Error para el ID 225426.0: '[1529] not in index'
# Error para el ID 242570.0: '[1529] not in index'
# Error para el ID 244870.0: '[1529] not in index'
# Error para el ID 224143.0: '[18584] not in index'
# Error para el ID 224145.0: '[6651, 7228] not in index'
# Error para el ID 224180.0: '[23619] not in index'
# Error para el ID 233592.0: '[12130] not in index'
# Error para el ID 222596.0: '[6696] not in index'
# Error para el ID 244060.0: '[14148] not in index'
# Error para el ID 215858.0: '[28606] not in index'
# Error para el ID 244810.0: '[7931] not in index'
# Error para el ID 249680.0: '[11308] not in index'
# Error para el ID 211992.0: '[20692] not in index'
# Error para el ID 243450.0: '[22984] not in index'
# Error para el ID 245030.0: '[6906] not in index'
# Error para el ID 249101.0: '[9226] not in index'
# Error para el ID 217920.0: '[27545] not in index'
# Error para el ID 246252.0: '[6651, 7228] not in index'
# Error para el ID 222602.0: '[20616] not in index'
# Error para el ID 245220.0: '[18189] not in index'
# Error para el ID 243040.0: '[6877] not in index'
# Error para el ID 248710.0: '[21794] not in index'
# Error para el ID 244690.0: '[16574] not in index'
# Error para el ID 241910.0: '[20113] not in index'
# Error para el ID 248190.0: '[14512] not in index'
# Error para el ID 259940.0: '[18274] not in index'
# Error para el ID 238271.0: '[14980] not in index'
# Error para el ID 258359.0: '[7067] not in index'
# Error para el ID 249110.0: '[10757, 20947] not in index'
# Error para el ID 258382.0: '[27545] not in index'
# Error para el ID 248370.0: '[9463, 9153] not in index'
# Error para el ID 226667.0: '[21492, 21414] not in index'
# Error para el ID 248630.0: '[22349] not in index'
# Error para el ID 66002.0: '[17913] not in index'
# Error para el ID 253370.0: '[7592] not in index'
# Error para el ID 261940.0: '[16473] not in index'
# Error para el ID 208370.0: '[12949] not in index'
# Error para el ID 247370.0: '[7425] not in index'
# Error para el ID 252370.0: '[21248] not in index'
# Error para el ID 259600.0: '[23619] not in index'
# Error para el ID 252250.0: '[19841] not in index'
# Error para el ID 258385.0: '[1846] not in index'
# Error para el ID 258376.0: '[22854] not in index'
# Error para el ID 257990.0: '[1846] not in index'
# Error para el ID 259830.0: '[8777] not in index'
# Error para el ID 258390.0: '[27040] not in index'
# Error para el ID 246840.0: '[22690, 18847] not in index'
# Error para el ID 268560.0: '[7874] not in index'
# Error para el ID 267600.0: '[4772] not in index'
# Error para el ID 241373.0: '[6997] not in index'
# Error para el ID 265090.0: '[19787] not in index'
# Error para el ID 226671.0: '[19317] not in index'
# Error para el ID 261395.0: '[27545] not in index'
# Error para el ID 261398.0: '[24732] not in index'
# Error para el ID 271415.0: '[13576] not in index'
# Error para el ID 260650.0: '[27040] not in index'
# Error para el ID 256510.0: '[27040] not in index'
# Error para el ID 271010.0: '[4772] not in index'
# Error para el ID 247305.0: '[27040] not in index'
# Error para el ID 260210.0: '[27040] not in index'
# Error para el ID 222613.0: '[27040] not in index'
# Error para el ID 272700.0: '[27040] not in index'
# Error para el ID 270700.0: '[27040] not in index'
# Error para el ID 267900.0: '[27040] not in index'
# Error para el ID 245050.0: '[19252] not in index'
# Error para el ID 273290.0: '[16965] not in index'
# Error para el ID 269150.0: '[13576] not in index'
# Error para el ID 222880.0: '[16450] not in index'
# Error para el ID 257630.0: '[8777] not in index'
# Error para el ID 263560.0: '[8777] not in index'
# Error para el ID 271950.0: '[7036] not in index'
# Error para el ID 271550.0: '[27040] not in index'
# Error para el ID 222627.0: '[27040] not in index'
# Error para el ID 203358.0: '[27040] not in index'
# Error para el ID 267980.0: '[27040] not in index'
# Error para el ID 253790.0: '[27040] not in index'
# Error para el ID 272060.0: '[27040] not in index'
# Error para el ID 271962.0: '[27040] not in index'
# Error para el ID 263880.0: '[27040] not in index'
# Error para el ID 271426.0: '[27040] not in index'
# Error para el ID 271429.0: '[1846] not in index'
# Error para el ID 271431.0: '[27040] not in index'
# Error para el ID 237890.0: '[27040] not in index'
# Error para el ID 269570.0: '[27040] not in index'
# Error para el ID 263300.0: '[27040] not in index'
# Error para el ID 226672.0: '[18157] not in index'
# Error para el ID 250600.0: '[11532] not in index'
# Error para el ID 261960.0: '[18157] not in index'
# Error para el ID 271820.0: '[22233, 21042] not in index'
# Error para el ID 271440.0: '[27040] not in index'
# Error para el ID 271438.0: '[27040] not in index'
# Error para el ID 271439.0: '[15642] not in index'
# Error para el ID 242920.0: '[27040] not in index'
# Error para el ID 284430.0: '[19607, 23240] not in index'
# Error para el ID 259250.0: '[17542] not in index'
# Error para el ID 269030.0: '[12803] not in index'
# Error para el ID 278711.0: '[1501] not in index'
# Error para el ID 271445.0: '[9088] not in index'
# Error para el ID 271446.0: '[15091, 13618, 18088] not in index'
# Error para el ID 271447.0: '[27040] not in index'
# Error para el ID 265610.0: '[27040] not in index'
# Error para el ID 279160.0: '[27545] not in index'
# Error para el ID 251510.0: '[27040] not in index'
# Error para el ID 256230.0: '[27040] not in index'
# Error para el ID 283550.0: '[27040] not in index'
# Error para el ID 283551.0: '[27040] not in index'
# Error para el ID 284700.0: '[23326] not in index'
# Error para el ID 281100.0: '[27040] not in index'
# Error para el ID 266010.0: '[27040] not in index'
# Error para el ID 265870.0: '[27545] not in index'
# Error para el ID 280560.0: '[20715] not in index'
# Error para el ID 286972.0: '[2281] not in index'
# Error para el ID 286960.0: '[2281] not in index'
# Error para el ID 286964.0: '[2281] not in index'
# Error para el ID 286961.0: '[7068, 18417] not in index'
# Error para el ID 286962.0: '[23619] not in index'
# Error para el ID 273151.0: '[14754] not in index'
# Error para el ID 279420.0: '[2120] not in index'
# Error para el ID 271466.0: '[27040] not in index'
# Error para el ID 218820.0: '[27040] not in index'
# Error para el ID 270050.0: '[1941] not in index'
# Error para el ID 273380.0: '[18846] not in index'
# Error para el ID 270650.0: '[18846] not in index'
# Error para el ID 286460.0: '[18846] not in index'
# Error para el ID 278481.0: '[18846] not in index'
# Error para el ID 284710.0: '[18846] not in index'
# Error para el ID 283370.0: '[18846] not in index'
# Error para el ID 289340.0: '[18846] not in index'
# Error para el ID 289380.0: '[18846] not in index'
# Error para el ID 289440.0: '[18846] not in index'
# Error para el ID 289480.0: '[18846] not in index'
# Error para el ID 289280.0: '[18846] not in index'
# Error para el ID 281341.0: '[8633] not in index'
# Error para el ID 292320.0: '[23757] not in index'
# Error para el ID 277430.0: '[790] not in index'
# Error para el ID 269110.0: '[9261] not in index'
# Error para el ID 291150.0: '[26191] not in index'
# Error para el ID 286500.0: '[18062] not in index'
# Error para el ID 271475.0: '[25015] not in index'
# Error para el ID 258851.0: '[24732] not in index'
# Error para el ID 256552.0: '[15579] not in index'
# Error para el ID 275804.0: '[20050] not in index'
# Error para el ID 256554.0: '[17913] not in index'
# Error para el ID 284000.0: '[26062, 51] not in index'
# Error para el ID 283940.0: '[26767] not in index'
# Error para el ID 293420.0: '[10906] not in index'
# Error para el ID 260130.0: '[19429] not in index'
# Error para el ID 282760.0: '[2542] not in index'
# Error para el ID 289800.0: '[10647] not in index'
# Error para el ID 292160.0: '[27545] not in index'
# Error para el ID 283270.0: '[23188] not in index'
# Error para el ID 264080.0: '[20243] not in index'
# Error para el ID 296210.0: '[18680] not in index'
# Error para el ID 289890.0: '[19226] not in index'
# Error para el ID 289320.0: '[22444] not in index'
# Error para el ID 227780.0: '[9492, 16526] not in index'
# Error para el ID 266050.0: '[27545] not in index'
# Error para el ID 298920.0: '[9350] not in index'
# Error para el ID 299100.0: '[26492] not in index'
# Error para el ID 299300.0: '[13720] not in index'
# Error para el ID 277820.0: '[13224] not in index'
# Error para el ID 285420.0: '[17975, 22204] not in index'
# Error para el ID 282740.0: '[17711] not in index'
# Error para el ID 227060.0: '[19, 14942] not in index'
# Error para el ID 284790.0: '[8777] not in index'
# Error para el ID 298140.0: '[23619] not in index'
# Error para el ID 301150.0: '[1846] not in index'
# Error para el ID 248570.0: '[25774, 21786] not in index'
# Error para el ID 266030.0: '[23619] not in index'
# Error para el ID 302460.0: '[17975] not in index'
# Error para el ID 289240.0: '[9088] not in index'
# Error para el ID 293860.0: '[11309] not in index'
# Error para el ID 301700.0: '[20891] not in index'
# Error para el ID 285110.0: '[26512] not in index'
# Error para el ID 242760.0: '[790] not in index'
# Error para el ID 302470.0: '[18063] not in index'
# Error para el ID 303730.0: '[1846] not in index'
# Error para el ID 267680.0: '[2281] not in index'
# Error para el ID 275170.0: '[2281] not in index'
# Error para el ID 268750.0: '[2281] not in index'
# Error para el ID 301740.0: '[2281] not in index'
# Error para el ID 294930.0: '[2281] not in index'
# Error para el ID 308140.0: '[23619] not in index'
# Error para el ID 297100.0: '[23619] not in index'
# Error para el ID 300320.0: '[11086] not in index'
# Error para el ID 222570.0: '[18157] not in index'
# Error para el ID 295430.0: '[18846] not in index'
# Error para el ID 295431.0: '[17006, 17008] not in index'
# Error para el ID 308163.0: '[20692, 22185] not in index'
# Error para el ID 306850.0: '[24195] not in index'
# Error para el ID 284580.0: '[16295] not in index'
# Error para el ID 287371.0: '[13576] not in index'
# Error para el ID 230230.0: '[21674] not in index'
# Error para el ID 256529.0: '[12487, 15588] not in index'
# Error para el ID 297590.0: '[9745, 11867, 14470] not in index'
# Error para el ID 241240.0: '[11233, 9008] not in index'
# Error para el ID 281060.0: '[2497] not in index'
# Error para el ID 302120.0: '[16379, 10555] not in index'
# Error para el ID 286730.0: '[9261] not in index'
# Error para el ID 304500.0: '[5706] not in index'
# Error para el ID 310410.0: '[9088] not in index'
# Error para el ID 310430.0: '[22052] not in index'
# Error para el ID 310440.0: '[8648, 5520] not in index'
# Error para el ID 312220.0: '[16574] not in index'
# Error para el ID 310070.0: '[19963] not in index'
# Error para el ID 310450.0: '[16794] not in index'
# Error para el ID 302590.0: '[17863] not in index'
# Error para el ID 268850.0: '[22194, 1501] not in index'
# Error para el ID 294280.0: '[5706] not in index'
# Error para el ID 265141.0: '[18255] not in index'
# Error para el ID 294965.0: '[20754] not in index'
# Error para el ID 307990.0: '[15053] not in index'
# Error para el ID 311020.0: '[10143] not in index'
# Error para el ID 312970.0: '[14072] not in index'
# Error para el ID 271942.0: '[4468] not in index'
# Error para el ID 301420.0: '[21984, 7056] not in index'
# Error para el ID 297512.0: '[12936] not in index'
# Error para el ID 288160.0: '[21564, 20220] not in index'
# Error para el ID 313980.0: '[27545] not in index'
# Error para el ID 316490.0: '[13873] not in index'
# Error para el ID 316491.0: '[5677] not in index'
# Error para el ID 360290.0: '[27545] not in index'
# Error para el ID 311550.0: '[25542] not in index'
# Error para el ID 251150.0: '[9233] not in index'
# Error para el ID 292200.0: '[20867] not in index'
# Error para el ID 312990.0: '[21036] not in index'
# Error para el ID 294974.0: '[8073] not in index'
# Error para el ID 293740.0: '[26535] not in index'
# Error para el ID 294975.0: '[5373] not in index'
# Error para el ID 317430.0: '[15526] not in index'
# Error para el ID 313620.0: '[2719] not in index'
# Error para el ID 306620.0: '[13720] not in index'
# Error para el ID 305920.0: '[19226] not in index'
# Error para el ID 277736.0: '[16033] not in index'
# Error para el ID 305186.0: '[16033] not in index'
# Error para el ID 314360.0: '[19981, 14401] not in index'
# Error para el ID 315920.0: '[790] not in index'
# Error para el ID 316867.0: '[6877] not in index'
# Error para el ID 316864.0: '[2538] not in index'
# Error para el ID 315550.0: '[26311] not in index'
# Error para el ID 316620.0: '[27545] not in index'
# Error para el ID 302210.0: '[18157] not in index'
# Error para el ID 286690.0: '[19042] not in index'
# Error para el ID 294990.0: '[2571] not in index'
# Error para el ID 261760.0: '[25360] not in index'
# Error para el ID 308380.0: '[2571] not in index'
# Error para el ID 316140.0: '[2585, 2587, 2586] not in index'
# Error para el ID 320570.0: '[2584] not in index'
# Error para el ID 312640.0: '[16723] not in index'
# Error para el ID 321030.0: '[27137] not in index'
# Error para el ID 321600.0: '[5677] not in index'
# Error para el ID 315151.0: '[9569] not in index'
# Error para el ID 288470.0: '[20194, 19741, 19740] not in index'
# Error para el ID 315150.0: '[19778] not in index'
# Error para el ID 246940.0: '[22439] not in index'
# Error para el ID 301893.0: '[2571] not in index'
# Error para el ID 313311.0: '[23619] not in index'
# Error para el ID 316500.0: '[9226] not in index'
# Error para el ID 316510.0: '[19226] not in index'
# Error para el ID 316542.0: '[5967] not in index'
# Error para el ID 297120.0: '[21637] not in index'
# Error para el ID 321710.0: '[19073] not in index'
# Error para el ID 299230.0: '[12055] not in index'
# Error para el ID 230860.0: '[10906] not in index'
# Error para el ID 317540.0: '[13655] not in index'
# Error para el ID 249190.0: '[21261] not in index'
# Error para el ID 315520.0: '[3600] not in index'
# Error para el ID 321870.0: '[12866] not in index'
# Error para el ID 312610.0: '[25680] not in index'
# Error para el ID 326760.0: '[23721] not in index'
# Error para el ID 318350.0: '[21804, 6640] not in index'
# Error para el ID 328020.0: '[16391] not in index'
# Error para el ID 327740.0: '[23619] not in index'
# Error para el ID 326610.0: '[25738] not in index'
# Error para el ID 322130.0: '[25738] not in index'
# Error para el ID 270190.0: '[14156] not in index'
# Error para el ID 306396.0: '[12877] not in index'
# Error para el ID 326960.0: '[27545] not in index'
# Error para el ID 325141.0: '[21489] not in index'
# Error para el ID 326431.0: '[25680] not in index'
# Error para el ID 321370.0: '[12195] not in index'
# Error para el ID 295040.0: '[21414, 21492] not in index'
# Error para el ID 285370.0: '[23648, 21473] not in index'
# Error para el ID 318402.0: '[26535] not in index'
# Error para el ID 330810.0: '[20113] not in index'
# Error para el ID 297110.0: '[21489] not in index'
# Error para el ID 250900.0: '[12647, 13179] not in index'
# Error para el ID 304380.0: '[18584] not in index'
# Error para el ID 326470.0: '[20806, 19781] not in index'
# Error para el ID 295042.0: '[8409] not in index'
# Error para el ID 295043.0: '[21489] not in index'
# Error para el ID 295044.0: '[22724] not in index'
# Error para el ID 329650.0: '[21804] not in index'
# Error para el ID 329630.0: '[26512] not in index'
# Error para el ID 329670.0: '[17763] not in index'
# Error para el ID 324130.0: '[18265] not in index'
# Error para el ID 321080.0: '[19551] not in index'
# Error para el ID 328230.0: '[27545] not in index'
# Error para el ID 319230.0: '[9129] not in index'
# Error para el ID 329100.0: '[24230] not in index'
# Error para el ID 314810.0: '[5677] not in index'
# Error para el ID 258406.0: '[15893] not in index'
# Error para el ID 333520.0: '[10565] not in index'
# Error para el ID 273850.0: '[27545] not in index'
# Error para el ID 310040.0: '[20244, 21415, 18625] not in index'
# Error para el ID 295790.0: '[21804] not in index'
# Error para el ID 310050.0: '[27545] not in index'
# Error para el ID 226560.0: '[27545] not in index'
# Error para el ID 330680.0: '[12647] not in index'
# Error para el ID 253510.0: '[18065] not in index'
# Error para el ID 328640.0: '[11686] not in index'
# Error para el ID 293340.0: '[18559, 12866] not in index'
# Error para el ID 333120.0: '[20459] not in index'
# Error para el ID 331400.0: '[19745] not in index'
# Error para el ID 321010.0: '[23481] not in index'
# Error para el ID 282513.0: '[22939] not in index'
# Error para el ID 334990.0: '[15855] not in index'
# Error para el ID 304010.0: '[16538] not in index'
# Error para el ID 325136.0: '[22019] not in index'
# Error para el ID 282960.0: '[19374] not in index'
# Error para el ID 318340.0: '[18189] not in index'
# Error para el ID 335320.0: '[27545] not in index'
# Error para el ID 316070.0: '[15738] not in index'
# Error para el ID 328890.0: '[5809] not in index'
# Error para el ID 334810.0: '[24195] not in index'
# Error para el ID 331440.0: '[22051] not in index'
# Error para el ID 337710.0: '[25503] not in index'
# Error para el ID 295076.0: '[19226] not in index'
# Error para el ID 336850.0: '[3049] not in index'
# Error para el ID 331350.0: '[3049] not in index'
# Error para el ID 331351.0: '[3049] not in index'
# Error para el ID 331352.0: '[3049] not in index'
# Error para el ID 286040.0: '[27545] not in index'
# Error para el ID 335050.0: '[19297] not in index'
# Error para el ID 338030.0: '[6740] not in index'
# Error para el ID 338230.0: '[9697] not in index'
# Error para el ID 339120.0: '[17551] not in index'
# Error para el ID 336770.0: '[8434] not in index'
# Error para el ID 340220.0: '[18427] not in index'
# Error para el ID 333760.0: '[26535] not in index'
# Error para el ID 295092.0: '[7355, 15443] not in index'
# Error para el ID 321990.0: '[16067] not in index'
# Error para el ID 335990.0: '[13326] not in index'
# Error para el ID 338090.0: '[25720, 8409] not in index'
# Error para el ID 337270.0: '[6640] not in index'
# Error para el ID 304540.0: '[16295] not in index'
# Error para el ID 303260.0: '[17038] not in index'
# Error para el ID 321880.0: '[21489] not in index'
# Error para el ID 334220.0: '[21489] not in index'
# Error para el ID 333084.0: '[21489] not in index'
# Error para el ID 333082.0: '[21489] not in index'
# Error para el ID 331071.0: '[21489] not in index'
# Error para el ID 333081.0: '[21489] not in index'
# Error para el ID 277742.0: '[23481] not in index'
# Error para el ID 343720.0: '[5712] not in index'
# Error para el ID 266590.0: '[17739] not in index'
# Error para el ID 313370.0: '[10762] not in index'
# Error para el ID 341210.0: '[18777] not in index'
# Error para el ID 313120.0: '[22215] not in index'
# Error para el ID 345650.0: '[7153] not in index'
# Error para el ID 338140.0: '[22056] not in index'
# Error para el ID 345790.0: '[9299] not in index'
# Error para el ID 344030.0: '[16796] not in index'
# Error para el ID 343430.0: '[17038] not in index'
# Error para el ID 331340.0: '[19252] not in index'
# Error para el ID 341060.0: '[15091] not in index'
# Error para el ID 345000.0: '[11608] not in index'
# Error para el ID 347492.0: '[17122] not in index'
# Error para el ID 348010.0: '[23117] not in index'
# Error para el ID 339240.0: '[19824] not in index'
# Error para el ID 318875.0: '[28606] not in index'
# Error para el ID 347480.0: '[11322] not in index'
# Error para el ID 342764.0: '[14272] not in index'
# Error para el ID 344050.0: '[12886] not in index'
# Error para el ID 348100.0: '[8331] not in index'
# Error para el ID 340120.0: '[11631, 20496] not in index'
# Error para el ID 307030.0: '[8997] not in index'
# Error para el ID 304650.0: '[12952, 19395, 16830] not in index'
# Error para el ID 342769.0: '[9113] not in index'
# Error para el ID 338320.0: '[21792] not in index'
# Error para el ID 348560.0: '[18933, 7934] not in index'
# Error para el ID 336670.0: '[9233] not in index'
# Error para el ID 326650.0: '[25950] not in index'
# Error para el ID 344220.0: '[8878] not in index'
# Error para el ID 339130.0: '[23651] not in index'
# Error para el ID 342774.0: '[22124] not in index'
# Error para el ID 342775.0: '[20614] not in index'
# Error para el ID 327470.0: '[23203] not in index'
# Error para el ID 337740.0: '[21791, 12499] not in index'
# Error para el ID 320383.0: '[23765] not in index'
# Error para el ID 320385.0: '[19041] not in index'
# Error para el ID 320386.0: '[21855] not in index'
# Error para el ID 320370.0: '[8300] not in index'
# Error para el ID 296280.0: '[19981, 14401] not in index'
# Error para el ID 353020.0: '[9654] not in index'
# Error para el ID 273500.0: '[6842] not in index'
# Error para el ID 323341.0: '[19572] not in index'
# Error para el ID 316610.0: '[13059, 12247] not in index'
# Error para el ID 244160.0: '[27545] not in index'
# Error para el ID 349530.0: '[17308] not in index'
# Error para el ID 322520.0: '[17515] not in index'
# Error para el ID 348680.0: '[17664] not in index'
# Error para el ID 342781.0: '[18677] not in index'
# Error para el ID 310810.0: '[8997] not in index'
# Error para el ID 340520.0: '[11091] not in index'
# Error para el ID 342570.0: '[23619] not in index'
# Error para el ID 355320.0: '[28698] not in index'
# Error para el ID 339031.0: '[27545] not in index'
# Error para el ID 347990.0: '[7888] not in index'
# Error para el ID 355520.0: '[9169] not in index'
# Error para el ID 348180.0: '[16566, 16855] not in index'
# Error para el ID 277758.0: '[19679] not in index'
# Error para el ID 352190.0: '[20646] not in index'
# Error para el ID 337630.0: '[20228] not in index'
# Error para el ID 352021.0: '[21905] not in index'
# Error para el ID 281940.0: '[21248] not in index'
# Error para el ID 342793.0: '[20459, 22421] not in index'
# Error para el ID 353051.0: '[18576] not in index'
# Error para el ID 341120.0: '[17233] not in index'
# Error para el ID 348530.0: '[23973] not in index'
# Error para el ID 306100.0: '[23973] not in index'
# Error para el ID 343070.0: '[23973] not in index'
# Error para el ID 347213.0: '[6027] not in index'
# Error para el ID 348700.0: '[10674, 5454, 20274] not in index'
# Error para el ID 245370.0: '[20490] not in index'
# Error para el ID 357290.0: '[13936] not in index'
# Error para el ID 356123.0: '[23720, 17875] not in index'
# Error para el ID 312230.0: '[12470, 9655] not in index'
# Error para el ID 354310.0: '[12751] not in index'
# Error para el ID 304030.0: '[25680] not in index'
# Error para el ID 279800.0: '[22007] not in index'
# Error para el ID 356440.0: '[25680] not in index'
# Error para el ID 358150.0: '[12032] not in index'
# Error para el ID 339840.0: '[8076] not in index'
# Error para el ID 341150.0: '[27545] not in index'
# Error para el ID 344630.0: '[21462] not in index'
# Error para el ID 357440.0: '[12876] not in index'
# Error para el ID 339460.0: '[12876] not in index'
# Error para el ID 311730.0: '[21674] not in index'
# Error para el ID 358140.0: '[12866] not in index'
# Error para el ID 358141.0: '[12803] not in index'
# Error para el ID 346420.0: '[21489] not in index'
# Error para el ID 336420.0: '[21489] not in index'
# Error para el ID 351930.0: '[21489] not in index'
# Error para el ID 329970.0: '[21489] not in index'
# Error para el ID 342801.0: '[21489] not in index'
# Error para el ID 342803.0: '[21489] not in index'
# Error para el ID 342804.0: '[21489] not in index'
# Error para el ID 342802.0: '[21489] not in index'
# Error para el ID 342805.0: '[21489] not in index'
# Error para el ID 342806.0: '[21489] not in index'
# Error para el ID 348400.0: '[21489] not in index'
# Error para el ID 339690.0: '[21489] not in index'
# Error para el ID 342430.0: '[21489] not in index'
# Error para el ID 355770.0: '[21489] not in index'
# Error para el ID 357770.0: '[21489] not in index'
# Error para el ID 342990.0: '[21489] not in index'
# Error para el ID 359810.0: '[21489] not in index'
# Error para el ID 357900.0: '[21489] not in index'
# Error para el ID 318490.0: '[21489] not in index'
# Error para el ID 360820.0: '[23973] not in index'
# Error para el ID 347250.0: '[23973] not in index'
# Error para el ID 239391.0: '[27545] not in index'
# Error para el ID 357370.0: '[7048] not in index'
# Error para el ID 361182.0: '[16851] not in index'
# Error para el ID 354680.0: '[19965] not in index'
# Error para el ID 355080.0: '[27545] not in index'
# Error para el ID 360111.0: '[23301] not in index'
# Error para el ID 360113.0: '[26535] not in index'
# Error para el ID 360115.0: '[18417, 7068] not in index'
# Error para el ID 360114.0: '[11288, 9859, 10317] not in index'
# Error para el ID 360120.0: '[19824] not in index'
# Error para el ID 360421.0: '[18501] not in index'
# Error para el ID 360424.0: '[17711] not in index'
# Error para el ID 360425.0: '[18841] not in index'
# Error para el ID 360422.0: '[10665] not in index'
# Error para el ID 361440.0: '[23642] not in index'
# Error para el ID 362280.0: '[21657] not in index'
# Error para el ID 222633.0: '[21674] not in index'
# Error para el ID 360600.0: '[1847] not in index'
# Error para el ID 300080.0: '[24131] not in index'
# Error para el ID 350490.0: '[15629, 7922] not in index'
# Error para el ID 340340.0: '[8166] not in index'
# Error para el ID 277520.0: '[6801] not in index'
# Error para el ID 325330.0: '[20234] not in index'
# Error para el ID 355140.0: '[22019] not in index'
# Error para el ID 324570.0: '[3372] not in index'
# Error para el ID 288930.0: '[20052, 12858] not in index'
# Error para el ID 306390.0: '[2989] not in index'
# Error para el ID 275200.0: '[18371, 22660] not in index'
# Error para el ID 353550.0: '[17785] not in index'
# Error para el ID 360750.0: '[26492] not in index'
# Error para el ID 362900.0: '[26492] not in index'
# Error para el ID 362050.0: '[26492] not in index'
# Error para el ID 348682.0: '[932, 18751] not in index'
# Error para el ID 348200.0: '[18051, 17556] not in index'
# Error para el ID 364400.0: '[13224] not in index'
# Error para el ID 316080.0: '[14059] not in index'
# Error para el ID 363220.0: '[14059] not in index'
# Error para el ID 285740.0: '[12515] not in index'
# Error para el ID 350070.0: '[3561] not in index'
# Error para el ID 350400.0: '[15091] not in index'
# Error para el ID 346770.0: '[3561] not in index'
# Error para el ID 365290.0: '[3561] not in index'
# Error para el ID 362660.0: '[3561] not in index'
# Error para el ID 365430.0: '[21520] not in index'
# Error para el ID 363330.0: '[10788, 5544] not in index'
# Error para el ID 366080.0: '[22233] not in index'
# Error para el ID 352120.0: '[4370] not in index'
# Error para el ID 352640.0: '[18091] not in index'
# Error para el ID 365340.0: '[23619] not in index'
# Error para el ID 360520.0: '[4077] not in index'
# Error para el ID 361520.0: '[3574] not in index'
# Error para el ID 365670.0: '[12193, 358] not in index'
# Error para el ID 262280.0: '[6740] not in index'
# Error para el ID 359890.0: '[19812] not in index'
# Error para el ID 324300.0: '[7248, 18057] not in index'
# Error para el ID 354260.0: '[23481] not in index'
# Error para el ID 365382.0: '[8506] not in index'
# Error para el ID 355341.0: '[21535] not in index'
# Error para el ID 345340.0: '[18939] not in index'
# Error para el ID 367060.0: '[8418] not in index'
# Error para el ID 365220.0: '[14558] not in index'
# Error para el ID 321380.0: '[20517] not in index'
# Error para el ID 356230.0: '[11635, 13358] not in index'
# Error para el ID 356231.0: '[14352] not in index'
# Error para el ID 357261.0: '[5654] not in index'
# Error para el ID 326622.0: '[9226] not in index'
# Error para el ID 326623.0: '[10799] not in index'
# Error para el ID 363200.0: '[8345] not in index'
# Error para el ID 317940.0: '[17020, 23133] not in index'
# Error para el ID 359040.0: '[8434] not in index'
# Error para el ID 320090.0: '[27545] not in index'
# Error para el ID 336150.0: '[16539] not in index'
# Error para el ID 354820.0: '[10429, 11757] not in index'
# Error para el ID 354425.0: '[26535] not in index'
# Error para el ID 366710.0: '[9142] not in index'
# Error para el ID 368910.0: '[12647] not in index'
# Error para el ID 226860.0: '[8506] not in index'
# Error para el ID 371400.0: '[21648] not in index'
# Error para el ID 371710.0: '[19919] not in index'
# Error para el ID 323650.0: '[15145] not in index'
# Error para el ID 342837.0: '[21901] not in index'
# Error para el ID 365520.0: '[25542] not in index'
# Error para el ID 342836.0: '[21901] not in index'
# Error para el ID 368320.0: '[21901] not in index'
# Error para el ID 341790.0: '[22444] not in index'
# Error para el ID 346340.0: '[21520] not in index'
# Error para el ID 363410.0: '[14213] not in index'
# Error para el ID 371070.0: '[4772] not in index'
# Error para el ID 365460.0: '[15945] not in index'
# Error para el ID 359930.0: '[9875] not in index'
# Error para el ID 373140.0: '[1847] not in index'
# Error para el ID 370040.0: '[10097] not in index'
# Error para el ID 342845.0: '[25774] not in index'
# Error para el ID 367210.0: '[24094] not in index'
# Error para el ID 373090.0: '[3735] not in index'
# Error para el ID 293520.0: '[13689] not in index'
# Error para el ID 359190.0: '[7590] not in index'
# Error para el ID 356540.0: '[12658] not in index'
# Error para el ID 317920.0: '[16069, 19838] not in index'
# Error para el ID 373180.0: '[8882] not in index'
# Error para el ID 346490.0: '[18598] not in index'
# Error para el ID 369502.0: '[12291] not in index'
# Error para el ID 364323.0: '[3561] not in index'
# Error para el ID 341680.0: '[23222] not in index'
# Error para el ID 260430.0: '[10565] not in index'
# Error para el ID 358840.0: '[20490] not in index'
# Error para el ID 371670.0: '[22051] not in index'
# Error para el ID 375890.0: '[23712] not in index'
# Error para el ID 314050.0: '[19717] not in index'
# Error para el ID 365760.0: '[19717] not in index'
# Error para el ID 372210.0: '[27545] not in index'
# Error para el ID 374890.0: '[18846] not in index'
# Error para el ID 312530.0: '[18219] not in index'
# Error para el ID 343593.0: '[20050] not in index'
# Error para el ID 343592.0: '[6065] not in index'
# Error para el ID 373460.0: '[27545] not in index'
# Error para el ID 372510.0: '[27545] not in index'
# Error para el ID 337830.0: '[18327, 7491] not in index'
# Error para el ID 367780.0: '[19772] not in index'
# Error para el ID 377760.0: '[13678] not in index'
# Error para el ID 322540.0: '[12154, 12794] not in index'
# Error para el ID 342853.0: '[20692] not in index'
# Error para el ID 370880.0: '[18846] not in index'
# Error para el ID 342856.0: '[13060] not in index'
# Error para el ID 335491.0: '[19305] not in index'
# Error para el ID 377180.0: '[27876] not in index'
# Error para el ID 351250.0: '[19478, 19126] not in index'
# Error para el ID 379030.0: '[12305] not in index'
# Error para el ID 338700.0: '[9997, 19624] not in index'
# Error para el ID 338690.0: '[19623] not in index'
# Error para el ID 376200.0: '[25720] not in index'
# Error para el ID 361560.0: '[8191] not in index'
# Error para el ID 379260.0: '[12149] not in index'
# Error para el ID 375120.0: '[21489] not in index'
# Error para el ID 379960.0: '[13801] not in index'
# Error para el ID 360850.0: '[10774] not in index'
# Error para el ID 352183.0: '[11831] not in index'
# Error para el ID 355641.0: '[8343] not in index'
# Error para el ID 277776.0: '[20585] not in index'
# Error para el ID 377660.0: '[4724] not in index'
# Error para el ID 373750.0: '[19812] not in index'
# Error para el ID 373810.0: '[14622] not in index'
# Error para el ID 350610.0: '[6721] not in index'
# Error para el ID 378400.0: '[8778] not in index'
# Error para el ID 363350.0: '[5809, 20539] not in index'
# Error para el ID 355670.0: '[15841] not in index'
# Error para el ID 383610.0: '[21795] not in index'
# Error para el ID 367700.0: '[18091] not in index'
# Error para el ID 368760.0: '[27279] not in index'
# Error para el ID 375550.0: '[23642, 20614] not in index'
# Error para el ID 384060.0: '[21389] not in index'
# Error para el ID 380910.0: '[12243] not in index'
# Error para el ID 383670.0: '[8549] not in index'
# Error para el ID 362970.0: '[17594] not in index'
# Error para el ID 384420.0: '[23768] not in index'
# Error para el ID 383660.0: '[13576] not in index'
# Error para el ID 383130.0: '[13059] not in index'
# Error para el ID 359160.0: '[13103] not in index'
# Error para el ID 360590.0: '[15129] not in index'
# Error para el ID 319280.0: '[17559] not in index'
# Error para el ID 384560.0: '[18505] not in index'
# Error para el ID 369773.0: '[23760] not in index'
# Error para el ID 384670.0: '[16391] not in index'
# Error para el ID 372200.0: '[23760] not in index'
# Error para el ID 385520.0: '[22387] not in index'
# Error para el ID 359250.0: '[13060] not in index'
# Error para el ID 385470.0: '[22522] not in index'
# Error para el ID 379350.0: '[23655] not in index'
# Error para el ID 387000.0: '[23655] not in index'
# Error para el ID 383810.0: '[23655] not in index'
# Error para el ID 292050.0: '[22854] not in index'
# Error para el ID 293260.0: '[22854] not in index'
# Error para el ID 356370.0: '[13344] not in index'
# Error para el ID 386760.0: '[17076] not in index'
# Error para el ID 361950.0: '[15834] not in index'
# Error para el ID 383560.0: '[21792] not in index'
# Error para el ID 343630.0: '[4637] not in index'
# Error para el ID 375870.0: '[19919] not in index'
# Error para el ID 385630.0: '[21036] not in index'
# Error para el ID 280360.0: '[20065] not in index'
# Error para el ID 384223.0: '[23640, 7380, 15667] not in index'
# Error para el ID 386160.0: '[23638] not in index'
# Error para el ID 388730.0: '[21287, 13224] not in index'
# Error para el ID 382760.0: '[19604, 6081] not in index'
# Error para el ID 354200.0: '[20113] not in index'
# Error para el ID 385870.0: '[7064] not in index'
# Error para el ID 377540.0: '[15053] not in index'
# Error para el ID 373360.0: '[14569] not in index'
# Error para el ID 386330.0: '[9261] not in index'
# Error para el ID 388670.0: '[14181] not in index'
# Error para el ID 382740.0: '[20574] not in index'
# Error para el ID 388340.0: '[23672, 23760] not in index'
# Error para el ID 388390.0: '[13224] not in index'
# Error para el ID 310890.0: '[5451] not in index'
# Error para el ID 381151.0: '[7162, 20672] not in index'
# Error para el ID 316430.0: '[21984] not in index'
# Error para el ID 354426.0: '[18538, 8353, 7064] not in index'
# Error para el ID 341870.0: '[8506] not in index'
# Error para el ID 368160.0: '[7506] not in index'
# Error para el ID 369782.0: '[7506] not in index'
# Error para el ID 369786.0: '[14959, 13816] not in index'
# Error para el ID 333817.0: '[23557] not in index'
# Error para el ID 388090.0: '[16858] not in index'
# Error para el ID 385960.0: '[22592, 19507] not in index'
# Error para el ID 362310.0: '[9989] not in index'
# Error para el ID 386260.0: '[10131] not in index'
# Error para el ID 361550.0: '[23760] not in index'
# Error para el ID 345180.0: '[13674] not in index'
# Error para el ID 380710.0: '[18417] not in index'
# Error para el ID 390020.0: '[2989] not in index'
# Error para el ID 385900.0: '[23487] not in index'
# Error para el ID 378550.0: '[10565] not in index'
# Error para el ID 387480.0: '[21986] not in index'
# Error para el ID 387590.0: '[23536] not in index'
# Error para el ID 348340.0: '[13175] not in index'
# Error para el ID 381220.0: '[13315] not in index'
# Error para el ID 317730.0: '[22969] not in index'
# Error para el ID 367990.0: '[21790] not in index'
# Error para el ID 388780.0: '[10762] not in index'
# Error para el ID 387630.0: '[5456, 5457] not in index'
# Error para el ID 324730.0: '[21489] not in index'
# Error para el ID 387890.0: '[21489] not in index'
# Error para el ID 292600.0: '[21489] not in index'
# Error para el ID 301860.0: '[23484] not in index'
# Error para el ID 390060.0: '[8434] not in index'
# Error para el ID 391830.0: '[5373] not in index'
# Error para el ID 376140.0: '[23692] not in index'
# Error para el ID 369795.0: '[21036] not in index'
# Error para el ID 347830.0: '[26492] not in index'
# Error para el ID 374230.0: '[26492] not in index'
# Error para el ID 383710.0: '[19538] not in index'
# Error para el ID 387070.0: '[8242] not in index'
# Error para el ID 315860.0: '[3700] not in index'
# Error para el ID 355450.0: '[23484] not in index'
# Error para el ID 390660.0: '[12926] not in index'
# Error para el ID 240620.0: '[21180] not in index'
# Error para el ID 365660.0: '[6424] not in index'
# Error para el ID 369798.0: '[19046] not in index'
# Error para el ID 340260.0: '[1847] not in index'
# Error para el ID 393550.0: '[6624, 21804] not in index'
# Error para el ID 392450.0: '[14001] not in index'
# Error para el ID 393580.0: '[10762] not in index'
# Error para el ID 394810.0: '[23424, 13296] not in index'
# Error para el ID 393270.0: '[16447] not in index'
# Error para el ID 250540.0: '[20050] not in index'
# Error para el ID 394400.0: '[9794, 16722] not in index'
# Error para el ID 368310.0: '[11202] not in index'
# Error para el ID 390980.0: '[17020, 23133] not in index'
# Error para el ID 382490.0: '[13659] not in index'
# Error para el ID 369803.0: '[7639] not in index'
# Error para el ID 369805.0: '[22522] not in index'
# Error para el ID 369806.0: '[18841] not in index'
# Error para el ID 395690.0: '[14072] not in index'
# Error para el ID 369807.0: '[14156, 13723] not in index'
# Error para el ID 392700.0: '[9133] not in index'
# Error para el ID 395150.0: '[23657] not in index'
# Error para el ID 391660.0: '[20425] not in index'
# Error para el ID 355350.0: '[21485] not in index'
# Error para el ID 330270.0: '[25774] not in index'
# Error para el ID 394350.0: '[23188] not in index'
# Error para el ID 388980.0: '[21878] not in index'
# Error para el ID 358650.0: '[21878] not in index'
# Error para el ID 322950.0: '[5737, 21879] not in index'
# Error para el ID 269690.0: '[23203] not in index'
# Error para el ID 393690.0: '[25720] not in index'
# Error para el ID 319910.0: '[1843] not in index'
# Error para el ID 390940.0: '[21603] not in index'
# Error para el ID 374530.0: '[21618] not in index'
# Error para el ID 395051.0: '[28472] not in index'
# Error para el ID 380840.0: '[11067] not in index'
# Error para el ID 396490.0: '[23222] not in index'
# Error para el ID 393730.0: '[9169] not in index'
# Error para el ID 336440.0: '[10774, 19469] not in index'
# Error para el ID 392020.0: '[23557, 9350] not in index'
# Error para el ID 393650.0: '[23263] not in index'
# Error para el ID 397400.0: '[23263] not in index'
# Error para el ID 395930.0: '[15125] not in index'
# Error para el ID 362680.0: '[24230] not in index'
# ...
# Error para el ID 6810.0: index 31881 is out of bounds for axis 0 with size 29644
# Error para el ID 6830.0: index 31882 is out of bounds for axis 0 with size 29644
# Error para el ID 6860.0: index 31883 is out of bounds for axis 0 with size 29644
# Error para el ID 2600.0: index 31884 is out of bounds for axis 0 with size 29644
# Error para el ID 4500.0: index 31885 is out of bounds for axis 0 with size 29644
# Error para el ID 6400.0: index 31886 is out of bounds for axis 0 with size 29644
# Error para el ID 6980.0: index 31887 is out of bounds for axis 0 with size 29644
# Error para el ID 6910.0: index 31888 is out of bounds for axis 0 with size 29644
# Error para el ID 6920.0: index 31889 is out of bounds for axis 0 with size 29644
# Error para el ID 7020.0: index 31890 is out of bounds for axis 0 with size 29644
# Error para el ID 7010.0: index 31891 is out of bounds for axis 0 with size 29644
# Error para el ID 7110.0: index 31892 is out of bounds for axis 0 with size 29644
# Error para el ID 6600.0: index 31893 is out of bounds for axis 0 with size 29644
# Error para el ID 3480.0: index 31894 is out of bounds for axis 0 with size 29644
# Error para el ID 4420.0: index 31895 is out of bounds for axis 0 with size 29644
# Error para el ID 6250.0: index 31896 is out of bounds for axis 0 with size 29644
# Error para el ID 7210.0: index 31897 is out of bounds for axis 0 with size 29644
# Error para el ID 7220.0: index 31898 is out of bounds for axis 0 with size 29644
# Error para el ID 4100.0: index 31899 is out of bounds for axis 0 with size 29644
# Error para el ID 2620.0: index 31900 is out of bounds for axis 0 with size 29644
# Error para el ID 3830.0: index 31901 is out of bounds for axis 0 with size 29644
# Error para el ID 2610.0: index 31902 is out of bounds for axis 0 with size 29644
# Error para el ID 2630.0: index 31903 is out of bounds for axis 0 with size 29644
# Error para el ID 2640.0: index 31904 is out of bounds for axis 0 with size 29644
# Error para el ID 1690.0: index 31905 is out of bounds for axis 0 with size 29644
# Error para el ID 3910.0: index 31906 is out of bounds for axis 0 with size 29644
# Error para el ID 3960.0: index 31907 is out of bounds for axis 0 with size 29644
# Error para el ID 3900.0: index 31908 is out of bounds for axis 0 with size 29644
# Error para el ID 2900.0: index 31909 is out of bounds for axis 0 with size 29644
# Error para el ID 2920.0: index 31910 is out of bounds for axis 0 with size 29644
# Error para el ID 2910.0: index 31911 is out of bounds for axis 0 with size 29644
# Error para el ID 3820.0: index 31912 is out of bounds for axis 0 with size 29644
# Error para el ID 201000.0: index 31913 is out of bounds for axis 0 with size 29644
# Error para el ID 4300.0: index 31914 is out of bounds for axis 0 with size 29644
# Error para el ID 4700.0: index 31915 is out of bounds for axis 0 with size 29644
# Error para el ID 4800.0: index 31916 is out of bounds for axis 0 with size 29644
# Error para el ID 774931.0: index 31917 is out of bounds for axis 0 with size 29644
# Error para el ID 692790.0: index 31920 is out of bounds for axis 0 with size 29644
# Error para el ID 736410.0: index 31921 is out of bounds for axis 0 with size 29644
# Error para el ID 767170.0: index 31924 is out of bounds for axis 0 with size 29644
# Error para el ID 768840.0: index 31925 is out of bounds for axis 0 with size 29644
# Error para el ID 768850.0: index 31926 is out of bounds for axis 0 with size 29644
# Error para el ID 768851.0: index 31927 is out of bounds for axis 0 with size 29644
# Error para el ID 768852.0: index 31928 is out of bounds for axis 0 with size 29644
# Error para el ID 768853.0: index 31929 is out of bounds for axis 0 with size 29644
# Error para el ID 768854.0: index 31930 is out of bounds for axis 0 with size 29644
# Error para el ID 768855.0: index 31931 is out of bounds for axis 0 with size 29644
# Error para el ID 768856.0: index 31932 is out of bounds for axis 0 with size 29644
# Error para el ID 581910.0: index 31935 is out of bounds for axis 0 with size 29644
# Error para el ID 769680.0: index 31936 is out of bounds for axis 0 with size 29644
# Error para el ID 769550.0: index 31937 is out of bounds for axis 0 with size 29644
# Error para el ID 765240.0: index 31938 is out of bounds for axis 0 with size 29644
# Error para el ID 656710.0: index 31940 is out of bounds for axis 0 with size 29644
# Error para el ID 764070.0: index 31944 is out of bounds for axis 0 with size 29644
# Error para el ID 565020.0: index 31945 is out of bounds for axis 0 with size 29644
# Error para el ID 769690.0: index 31946 is out of bounds for axis 0 with size 29644
# Error para el ID 768820.0: index 31947 is out of bounds for axis 0 with size 29644
# Error para el ID 671090.0: index 31948 is out of bounds for axis 0 with size 29644
# Error para el ID 765610.0: index 31949 is out of bounds for axis 0 with size 29644
# Error para el ID 765200.0: index 31955 is out of bounds for axis 0 with size 29644
# Error para el ID 776950.0: index 31957 is out of bounds for axis 0 with size 29644
# Error para el ID 767500.0: index 31961 is out of bounds for axis 0 with size 29644
# Error para el ID 765390.0: index 31963 is out of bounds for axis 0 with size 29644
# Error para el ID 771140.0: index 31966 is out of bounds for axis 0 with size 29644
# Error para el ID 700330.0: index 31967 is out of bounds for axis 0 with size 29644
# Error para el ID 768310.0: index 31969 is out of bounds for axis 0 with size 29644
# Error para el ID 766810.0: index 31970 is out of bounds for axis 0 with size 29644
# Error para el ID 655010.0: index 31971 is out of bounds for axis 0 with size 29644
# Error para el ID 767410.0: index 31972 is out of bounds for axis 0 with size 29644
# Error para el ID 610730.0: index 31973 is out of bounds for axis 0 with size 29644
# Error para el ID 596740.0: index 31974 is out of bounds for axis 0 with size 29644
# Error para el ID 755150.0: index 31975 is out of bounds for axis 0 with size 29644
# Error para el ID 771200.0: index 31976 is out of bounds for axis 0 with size 29644
# Error para el ID 761100.0: index 31977 is out of bounds for axis 0 with size 29644
# Error para el ID 763090.0: index 31978 is out of bounds for axis 0 with size 29644
# Error para el ID 749540.0: index 31982 is out of bounds for axis 0 with size 29644
# Error para el ID 685130.0: index 31984 is out of bounds for axis 0 with size 29644
# Error para el ID 775660.0: index 31985 is out of bounds for axis 0 with size 29644
# Error para el ID 747850.0: index 31986 is out of bounds for axis 0 with size 29644
# Error para el ID 766600.0: index 31989 is out of bounds for axis 0 with size 29644
# Error para el ID 754810.0: index 31991 is out of bounds for axis 0 with size 29644
# Error para el ID 754820.0: index 31993 is out of bounds for axis 0 with size 29644
# Error para el ID 746050.0: index 31995 is out of bounds for axis 0 with size 29644
# Error para el ID 246920.0: index 31996 is out of bounds for axis 0 with size 29644
# Error para el ID 470310.0: index 31999 is out of bounds for axis 0 with size 29644
# Error para el ID 727460.0: index 32000 is out of bounds for axis 0 with size 29644
# Error para el ID 768430.0: index 32001 is out of bounds for axis 0 with size 29644
# Error para el ID 765620.0: index 32002 is out of bounds for axis 0 with size 29644
# Error para el ID 735250.0: index 32004 is out of bounds for axis 0 with size 29644
# Error para el ID 717990.0: index 32005 is out of bounds for axis 0 with size 29644
# Error para el ID 748110.0: index 32007 is out of bounds for axis 0 with size 29644
# Error para el ID 667590.0: index 32009 is out of bounds for axis 0 with size 29644
# Error para el ID 240.0: index 32010 is out of bounds for axis 0 with size 29644
# Error para el ID 280.0: index 32011 is out of bounds for axis 0 with size 29644
# Error para el ID 90044.0: index 32012 is out of bounds for axis 0 with size 29644
# Error para el ID 320.0: index 32013 is out of bounds for axis 0 with size 29644
# Error para el ID 220.0: index 32014 is out of bounds for axis 0 with size 29644
# Error para el ID 200990.0: index 32015 is out of bounds for axis 0 with size 29644
# Error para el ID 3920.0: index 32016 is out of bounds for axis 0 with size 29644
# Error para el ID 1500.0: index 32017 is out of bounds for axis 0 with size 29644
# Error para el ID 340.0: index 32018 is out of bounds for axis 0 with size 29644
# Error para el ID 1002.0: index 32019 is out of bounds for axis 0 with size 29644
# Error para el ID 39200.0: index 32020 is out of bounds for axis 0 with size 29644
# Error para el ID 1200.0: index 32021 is out of bounds for axis 0 with size 29644
# Error para el ID 1610.0: index 32022 is out of bounds for axis 0 with size 29644
# Error para el ID 1600.0: index 32023 is out of bounds for axis 0 with size 29644
# Error para el ID 1900.0: index 32024 is out of bounds for axis 0 with size 29644
# Error para el ID 360.0: index 32025 is out of bounds for axis 0 with size 29644
# Error para el ID 2500.0: index 32026 is out of bounds for axis 0 with size 29644
# Error para el ID 380.0: index 32027 is out of bounds for axis 0 with size 29644
# Error para el ID 1300.0: index 32028 is out of bounds for axis 0 with size 29644
# Error para el ID 1620.0: index 32029 is out of bounds for axis 0 with size 29644
# Error para el ID 2810.0: index 32030 is out of bounds for axis 0 with size 29644
# Error para el ID 2800.0: index 32031 is out of bounds for axis 0 with size 29644
# Error para el ID 1670.0: index 32032 is out of bounds for axis 0 with size 29644
# Error para el ID 1510.0: index 32033 is out of bounds for axis 0 with size 29644
# Error para el ID 3010.0: index 32034 is out of bounds for axis 0 with size 29644
# Error para el ID 3410.0: index 32035 is out of bounds for axis 0 with size 29644
# Error para el ID 3450.0: index 32036 is out of bounds for axis 0 with size 29644
# Error para el ID 3460.0: index 32037 is out of bounds for axis 0 with size 29644
# Error para el ID 3430.0: index 32038 is out of bounds for axis 0 with size 29644
# Error para el ID 3350.0: index 32039 is out of bounds for axis 0 with size 29644
# Error para el ID 3420.0: index 32040 is out of bounds for axis 0 with size 29644
# Error para el ID 3440.0: index 32041 is out of bounds for axis 0 with size 29644
# Error para el ID 3380.0: index 32042 is out of bounds for axis 0 with size 29644
# Error para el ID 3400.0: index 32043 is out of bounds for axis 0 with size 29644
# Error para el ID 3340.0: index 32044 is out of bounds for axis 0 with size 29644
# Error para el ID 3360.0: index 32045 is out of bounds for axis 0 with size 29644
# Error para el ID 3390.0: index 32046 is out of bounds for axis 0 with size 29644
# Error para el ID 3330.0: index 32047 is out of bounds for axis 0 with size 29644
# Error para el ID 3310.0: index 32048 is out of bounds for axis 0 with size 29644
# Error para el ID 3300.0: index 32049 is out of bounds for axis 0 with size 29644
# Error para el ID 2100.0: index 32050 is out of bounds for axis 0 with size 29644
# Error para el ID 3320.0: index 32051 is out of bounds for axis 0 with size 29644
# Error para el ID 718050.0: index 32054 is out of bounds for axis 0 with size 29644
# Error para el ID 763740.0: index 32058 is out of bounds for axis 0 with size 29644
# Error para el ID 752400.0: index 32059 is out of bounds for axis 0 with size 29644
# Error para el ID 751660.0: index 32060 is out of bounds for axis 0 with size 29644
# Error para el ID 756380.0: index 32061 is out of bounds for axis 0 with size 29644
# Error para el ID 773170.0: index 32062 is out of bounds for axis 0 with size 29644
# Error para el ID 698030.0: index 32063 is out of bounds for axis 0 with size 29644
# Error para el ID 775690.0: index 32064 is out of bounds for axis 0 with size 29644
# Error para el ID 768580.0: index 32065 is out of bounds for axis 0 with size 29644
# Error para el ID 765400.0: index 32067 is out of bounds for axis 0 with size 29644
# Error para el ID 719590.0: index 32068 is out of bounds for axis 0 with size 29644
# Error para el ID 513500.0: index 32070 is out of bounds for axis 0 with size 29644
# Error para el ID 766460.0: index 32072 is out of bounds for axis 0 with size 29644
# Error para el ID 767240.0: index 32073 is out of bounds for axis 0 with size 29644
# Error para el ID 769600.0: index 32076 is out of bounds for axis 0 with size 29644
# Error para el ID 772450.0: index 32077 is out of bounds for axis 0 with size 29644
# Error para el ID 772190.0: index 32078 is out of bounds for axis 0 with size 29644
# Error para el ID 765180.0: index 32084 is out of bounds for axis 0 with size 29644
# Error para el ID 759900.0: index 32087 is out of bounds for axis 0 with size 29644
# Error para el ID 770520.0: index 32088 is out of bounds for axis 0 with size 29644
# Error para el ID 737750.0: index 32089 is out of bounds for axis 0 with size 29644
# Error para el ID 524350.0: index 32090 is out of bounds for axis 0 with size 29644
# Error para el ID 760300.0: index 32091 is out of bounds for axis 0 with size 29644
# Error para el ID 776420.0: index 32092 is out of bounds for axis 0 with size 29644
# Error para el ID 763320.0: index 32093 is out of bounds for axis 0 with size 29644
# Error para el ID 766700.0: index 32094 is out of bounds for axis 0 with size 29644
# Error para el ID 755310.0: index 32096 is out of bounds for axis 0 with size 29644
# Error para el ID 771070.0: index 32097 is out of bounds for axis 0 with size 29644
# Error para el ID 754350.0: index 32098 is out of bounds for axis 0 with size 29644
# Error para el ID 754620.0: index 32099 is out of bounds for axis 0 with size 29644
# Error para el ID 771610.0: index 32100 is out of bounds for axis 0 with size 29644
# Error para el ID 20.0: index 32101 is out of bounds for axis 0 with size 29644
# Error para el ID 50.0: index 32102 is out of bounds for axis 0 with size 29644
# Error para el ID 60.0: index 32103 is out of bounds for axis 0 with size 29644
# Error para el ID 10.0: index 32104 is out of bounds for axis 0 with size 29644
# Error para el ID 65540.0: index 32105 is out of bounds for axis 0 with size 29644
# Error para el ID 40.0: index 32106 is out of bounds for axis 0 with size 29644
# Error para el ID 130.0: index 32107 is out of bounds for axis 0 with size 29644
# Error para el ID 200960.0: index 32108 is out of bounds for axis 0 with size 29644
# Error para el ID 90007.0: index 32109 is out of bounds for axis 0 with size 29644
# Error para el ID 40990.0: index 32110 is out of bounds for axis 0 with size 29644
# Error para el ID 259340.0: index 32111 is out of bounds for axis 0 with size 29644
# Error para el ID 30.0: index 32112 is out of bounds for axis 0 with size 29644
# Error para el ID 200980.0: index 32113 is out of bounds for axis 0 with size 29644
# Error para el ID 13230.0: index 32114 is out of bounds for axis 0 with size 29644
# Error para el ID 80.0: index 32115 is out of bounds for axis 0 with size 29644
# Error para el ID 775640.0: index 32116 is out of bounds for axis 0 with size 29644
# Error para el ID 777930.0: index 32117 is out of bounds for axis 0 with size 29644
# Error para el ID 775370.0: index 32118 is out of bounds for axis 0 with size 29644
# Error para el ID 777950.0: index 32119 is out of bounds for axis 0 with size 29644
# Error para el ID 767010.0: index 32120 is out of bounds for axis 0 with size 29644
# Error para el ID 761480.0: index 32122 is out of bounds for axis 0 with size 29644
# Error para el ID 771810.0: index 32123 is out of bounds for axis 0 with size 29644
# Error para el ID 767590.0: index 32124 is out of bounds for axis 0 with size 29644
# Error para el ID 747320.0: index 32125 is out of bounds for axis 0 with size 29644
# Error para el ID 769330.0: index 32126 is out of bounds for axis 0 with size 29644
# Error para el ID 745400.0: index 32127 is out of bounds for axis 0 with size 29644
# Error para el ID 773640.0: index 32128 is out of bounds for axis 0 with size 29644
# Error para el ID 733530.0: index 32129 is out of bounds for axis 0 with size 29644
# Error para el ID 610660.0: index 32130 is out of bounds for axis 0 with size 29644
# Error para el ID 658870.0: index 32131 is out of bounds for axis 0 with size 29644

# %% [markdown]
# 3.7. Crear dataframe del diciconario obtenido:

# %%
# Crear listas para almacenar datos
ids = []
recommended_ids = []

# Iterar sobre el diccionario y crear las listas
for key, values in dic_similitud.items():
    ids.extend([key] * len(values))
    recommended_ids.extend(values)

# Crear un DataFrame a partir de las listas
similitud_df = pd.DataFrame({'id': ids, 'recommended_id': recommended_ids})

# Imprimir el DataFrame resultante
similitud_df
# Out:
#              id                                     recommended_id
# 0      670290.0                                           670290.0
# 1      670290.0  [614300.0, 605490.0, 608590.0, 505750.0, 49295...
# 2      767400.0                                           767400.0
# 3      767400.0   [720850.0, 72500.0, 464525.0, 45302.0, 484860.0]
# 4      772540.0                                           772540.0
# ...         ...                                                ...
# 36533  263340.0  [680340.0, 349760.0, 717190.0, 461780.0, 35734...
# 36534  263380.0                                           263380.0
# 36535  263380.0  [271860.0, 762350.0, 439910.0, 639530.0, 73511...
# 36536  264320.0                                           264320.0
# 36537  264320.0  [610698.0, 645440.0, 641870.0, 591940.0, 43305...
#
# [36538 rows x 2 columns]

# %%
# Filtrar solo las filas donde 'recommended_id' es una lista
similitud_df = similitud_df[similitud_df['recommended_id'].apply(lambda x: isinstance(x, list))]

# Restablecer los índices después de la filtración
similitud_df.reset_index(drop=True, inplace=True)

# Imprimir el DataFrame resultante
similitud_df
# Out:
#              id                                     recommended_id
# 0      670290.0  [614300.0, 605490.0, 608590.0, 505750.0, 49295...
# 1      767400.0   [720850.0, 72500.0, 464525.0, 45302.0, 484860.0]
# 2      772540.0  [768880.0, 774276.0, 774277.0, 773650.0, 23774...
# 3      774276.0  [774276.0, 774277.0, 768880.0, 772540.0, 23774...
# 4      774277.0  [774276.0, 774277.0, 768880.0, 772540.0, 23774...
# ...         ...                                                ...
# 18264  267652.0  [271474.0, 256611.0, 376956.0, 572700.0, 50549...
# 18265  267650.0  [289881.0, 260550.0, 433450.0, 287700.0, 31173...
# 18266  263340.0  [680340.0, 349760.0, 717190.0, 461780.0, 35734...
# 18267  263380.0  [271860.0, 762350.0, 439910.0, 639530.0, 73511...
# 18268  264320.0  [610698.0, 645440.0, 641870.0, 591940.0, 43305...
#
# [18269 rows x 2 columns]

# %% [markdown]
# 3.8. Creamos tablas de nombres

# %%
names = pd.read_csv('Clean_Data\\SGames_CD.csv', quotechar='"')
names=names[['id','app_name']]

# %% [markdown]
# 3.9. Exportamos nuevo dataframe con id y los id recomendados por similitud de coseno y tabla de nombres:

# %%
# Exportar el DataFrame a CSV:

similitud_df.to_csv('Data_Queries/similitud_df.csv', index=False)
print(f"DataFrame exportado a {'Data_Queries/similitud_df.csv'}")

names.to_csv('Data_Queries/names.csv', index=False)
print(f"DataFrame exportado a {'Data_Queries/names.csv'}")
# Out:
# DataFrame exportado a Data_Queries/similitud_df.csv
# DataFrame exportado a Data_Queries/names.csv

# %% [markdown]
# 3.10. Crear función para la Fastapi:

# %%
def obtener_nombres_recomendados(id_seleccionado):
    try:
        # Obtener el nombre del juego seleccionado
        nombre_seleccionado = names.loc[names['id'] == id_seleccionado, 'app_name'].iloc[0]

        # Obtener los IDs de los juegos recomendados
        juegos_recomendados_ids = similitud_df.loc[similitud_df['id'] == id_seleccionado, 'recommended_id'].iloc[0]

        # Obtener los nombres de los juegos recomendados
        nombres_recomendados = []
        for id_recomendado in juegos_recomendados_ids:
            nombre_recomendado = names.loc[names['id'] == id_recomendado, 'app_name'].iloc[0]
            nombres_recomendados.append(nombre_recomendado)

        # Crear y devolver el diccionario
        diccionario_resultado = {'nombre_seleccionado': nombre_seleccionado, 'nombres_recomendados': nombres_recomendados}
        return diccionario_resultado

    except IndexError:
        print(f"No se encontró nombre para el ID seleccionado {id_seleccionado}")

    except KeyError:
        print(f"No se encontraron recomendaciones para el ID seleccionado {id_seleccionado}")

    except Exception as e:
        print(f"Error inesperado: {str(e)}")

# %% [markdown]
# 3.11. Probar función:

# %%
# Ejemplo de uso
id_seleccionado = 670290  # Ingresa el ID deseado
resultado = obtener_nombres_recomendados(id_seleccionado)
print(resultado)
# Out:
# {'nombre_seleccionado': 'Real Pool 3D - Poolians', 'nombres_recomendados': ['Fantasy Grounds - Mini-Dungeon #023: The Aura of Profit (5E)', 'One Hit KO', 'Hack_me 2 - Wallpapers', 'Trimmer Tycoon', 'Rocksmith® 2014 – 2010s Mix Song Pack']}
